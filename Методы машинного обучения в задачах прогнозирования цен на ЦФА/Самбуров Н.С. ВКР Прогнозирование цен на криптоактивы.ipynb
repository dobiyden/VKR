# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt 
from chart_studio import plotly
from plotly import tools
import chart_studio.plotly as py
from plotly.offline import init_notebook_mode, iplot
init_notebook_mode(connected=True)
import plotly.graph_objs as go
import gc
import seaborn as sns
import datetime, pytz
import torch
import pmdarima as pm
import statsmodels.api as sm
from statsmodels.tsa.arima_model import ARIMA
from statsmodels.tsa.statespace.sarimax import SARIMAX
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from dateutil.parser import parse
from numpy import log
from statsmodels.tsa.stattools import acf
import random
from statsmodels.tsa.stattools import adfuller, kpss
from sklearn.preprocessing import MinMaxScaler
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, GRU, Bidirectional
from tensorflow.keras.optimizers import Adam
import os
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
from pylab import rcParams
rcParams['figure.figsize'] = 10, 6
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from pmdarima.arima import auto_arima
from pylab import rcParams
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf
from sklearn.metrics import mean_squared_error, mean_absolute_error
import math
from statsmodels.tsa.api import  SimpleExpSmoothing
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.20.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
dateparse = lambda dates: pd.datetime.strptime(dates, '%Y-%m-%d')
stock_data = pd.read_csv('btc.txt',sep=',',
                         index_col='Date', parse_dates=['Date'], date_parser=dateparse).fillna(0)

# %%
stock_data
# Out:
#                     Open          High           Low         Close  \
# Date
# 2017-01-01    963.650000   1003.080000    958.690000    998.325000
# 2017-01-02    998.617000   1031.390000    996.702000   1021.750000
# 2017-01-03   1021.599976   1044.079956   1021.599976   1043.839966
# 2017-01-04   1044.400024   1159.420044   1044.400024   1154.729980
# 2017-01-05   1156.729980   1191.099976    910.416992   1013.380005
# ...                  ...           ...           ...           ...
# 2023-04-16  30315.976420  30555.537630  30157.832330  30315.355460
# 2023-04-17  30317.145700  30319.196580  29275.371060  29445.044900
# 2023-04-18  29449.091700  30470.302010  29154.849370  30397.552740
# 2023-04-19  30394.187900  30411.053790  28669.898270  28822.680470
# 2023-04-20  28823.682860  29076.401050  28037.257260  28245.987310
#
#                  Volume
# Date
# 2017-01-01    147775008
# 2017-01-02    222184992
# 2017-01-03    185168000
# 2017-01-04    344945984
# 2017-01-05    510199008
# ...                 ...
# 2023-04-16  12854816417
# 2023-04-17  17872186762
# 2023-04-18  19480529496
# 2023-04-19  24571565421
# 2023-04-20  21340360360
#
# [2301 rows x 5 columns]

# %%
stock_data = stock_data.drop('High', axis=1)
stock_data = stock_data.drop('Low', axis=1)
stock_data = stock_data.drop('Close', axis=1)
stock_data = stock_data.drop('Volume', axis=1)
stock_data = stock_data.rename(columns={'Open': 'Price'})
stock_data
# Out:
#                    Price
# Date
# 2017-01-01    963.650000
# 2017-01-02    998.617000
# 2017-01-03   1021.599976
# 2017-01-04   1044.400024
# 2017-01-05   1156.729980
# ...                  ...
# 2023-04-16  30315.976420
# 2023-04-17  30317.145700
# 2023-04-18  29449.091700
# 2023-04-19  30394.187900
# 2023-04-20  28823.682860
#
# [2301 rows x 1 columns]

# %%
stock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 2301 entries, 2017-01-01 to 2023-04-20
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Price   2301 non-null   float64
# dtypes: float64(1)
# memory usage: 36.0 KB

# %%
stock_data.isnull().sum()
# Out:
# Price    0
# dtype: int64

# %%
plt.figure(figsize=(14,8))
plt.grid(True)
plt.xlabel('Год')
plt.ylabel('Стоимость')
plt.plot(stock_data)
plt.title('Стоимость Bitcoin (2017-2023)')
plt.show()

# %% [markdown]
# # Анализ

# %%
result = seasonal_decompose(stock_data['Price'], model='additive')

# Построение графиков тренда, остатков и сезонности
plt.figure(figsize=(10, 8))

plt.subplot(2, 1, 1)
plt.plot(result.trend, label='Trend')
plt.legend(loc='best')
plt.title('Trend')

plt.subplot(2, 1, 2)
plt.plot(result.resid, label='Residuals')
plt.legend(loc='best')
plt.title('Residuals')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(15,7))
ax = plt.subplot(211)
sm.graphics.tsa.plot_acf(stock_data.squeeze(), lags=50, ax=ax)
plt.tight_layout()
plt.show()

# %% [markdown]
# #### Тест стационарности и преобразование

# %%
def test_stationarity(timeseries):
    
    rolmean = timeseries.rolling(12).mean()
    rolstd = timeseries.rolling(12).std()
    
    plt.plot(timeseries, color='blue',label='Изначальные значения')
    plt.plot(rolmean, color='red', label='Скользящее среднее')
    plt.legend(loc='best')
    plt.title('Скользящее среднее')
    plt.show(block=False)
    
test_stationarity(stock_data)

# %%
def adf_test(timeseries):
    print("Результаты теста ADF:")
    dftest = adfuller(timeseries, autolag="AIC")
    dfoutput = pd.Series(
        dftest[0:3],
        index=[
            "Статистический критерий",
            "p-value",
            "Число лагов",
        ],
    )
    for key, value in dftest[4].items():
        dfoutput["Критическое значение (%s)" % key] = value
    print(dfoutput)
    
adf_test(stock_data)
# Out:
# Результаты теста ADF:
# Статистический критерий       -1.655783
# p-value                        0.454026
# Число лагов                   27.000000
# Критическое значение (1%)     -3.433230
# Критическое значение (5%)     -2.862812
# Критическое значение (10%)    -2.567447
# dtype: float64

# %%
def kpss_test(timeseries):
    print("Результаты теста KPSS:")
    kpsstest = kpss(timeseries, regression="c", nlags="auto")
    kpss_output = pd.Series(
        kpsstest[0:3], index=["Статистический критерий", "p-value", "Число лагов"]
    )
    for key, value in kpsstest[3].items():
        kpss_output["Критическое значение (%s)" % key] = value
    print(kpss_output)
    
kpss_test(stock_data)
# Out:
# Результаты теста KPSS:
# Статистический критерий         4.357005
# p-value                         0.010000
# Число лагов                    29.000000
# Критическое значение (10%)      0.347000
# Критическое значение (5%)       0.463000
# Критическое значение (2.5%)     0.574000
# Критическое значение (1%)       0.739000
# dtype: float64

# %%
alpha = 0.005  
exponential_smoothed = stock_data['Price'].ewm(alpha=alpha, adjust=False).mean()

# Построение графика
plt.figure(figsize=(15, 8))
plt.plot(stock_data.index, stock_data['Price'], label='Исходные данные')
plt.plot(stock_data.index, exponential_smoothed, label='Exponential Smoothing')
plt.title('Экспоненциальное сглаживание')
plt.xlabel('Дата')
plt.ylabel('Цена')
plt.legend()
plt.show()

# %% [markdown]
# # Метрики оценивания

# %%
def toFixed(numObj, digits=0):
    return f"{numObj:.{digits}f}"

def metrics(forecast, test):
    mae = mean_absolute_error(test, forecast)
    rmse = np.sqrt(mean_squared_error(test, forecast))
    mean_obs = test.mean()
    si = (rmse/mean_obs)*100
    mape = np.mean(np.abs((test - forecast) / test))*100
    
    return mae, rmse, si, mape

# %% [markdown]
# # Разделение выборки и построение ARIMA

# %%
stock_data['Price'] = exponential_smoothed

# %%
train_size = int(len(stock_data) * 0.85)
train_data = stock_data.iloc[:train_size]
test_data = stock_data.iloc[train_size:]

# %%
plt.figure(figsize=(15,8))
plt.grid(True)
plt.xlabel('Год')
plt.ylabel('Стоимость')
plt.plot(train_data, 'blue', label='Обучающие данные')
plt.plot(test_data, 'red', label='Тестовые данные')
plt.legend()

# %% [markdown]
# Подбор параметров при помощи auto_arima

# %%
model_autoARIMA = auto_arima(train_data, start_p=0, start_q=0,
                      test='adf',       
                      max_p=3, max_q=3, 
                      m=1,              
                      d=None,           
                      seasonal=False,   
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)
print(model_autoARIMA.summary())
plt.show()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(0,2,0)(0,0,0)[0] intercept   : AIC=11662.421, Time=0.03 sec
#  ARIMA(1,2,0)(0,0,0)[0] intercept   : AIC=11661.870, Time=0.07 sec
#  ARIMA(0,2,1)(0,0,0)[0] intercept   : AIC=11661.829, Time=0.09 sec
#  ARIMA(0,2,0)(0,0,0)[0]             : AIC=11660.458, Time=0.02 sec
#  ARIMA(1,2,1)(0,0,0)[0] intercept   : AIC=11663.788, Time=0.37 sec
#
# Best model:  ARIMA(0,2,0)(0,0,0)[0]
# Total fit time: 0.586 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                 1955
# Model:               SARIMAX(0, 2, 0)   Log Likelihood               -5829.229
# Date:                Fri, 19 May 2023   AIC                          11660.458
# Time:                        20:39:53   BIC                          11666.035
# Sample:                             0   HQIC                         11662.508
#                                - 1955
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# sigma2        22.9114      0.283     80.996      0.000      22.357      23.466
# ===================================================================================
# Ljung-Box (L1) (Q):                   2.55   Jarque-Bera (JB):             10662.88
# Prob(Q):                              0.11   Prob(JB):                         0.00
# Heteroskedasticity (H):              14.66   Skew:                            -0.30
# Prob(H) (two-sided):                  0.00   Kurtosis:                        14.43
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model = ARIMA(train_data, order=(0,2,0))  
fitted = model.fit(disp=-1)  
print(fitted.summary())
# Out:
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:               D2.Price   No. Observations:                 1953
# Model:                 ARIMA(0, 2, 0)   Log Likelihood               -5829.210
# Method:                           css   S.D. of innovations              4.787
# Date:                Fri, 19 May 2023   AIC                          11662.421
# Time:                        20:39:54   BIC                          11673.575
# Sample:                    01-03-2017   HQIC                         11666.521
#                          - 05-09-2022
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.0209      0.108     -0.193      0.847      -0.233       0.191
# ==============================================================================

# %%
fc, se, conf = fitted.forecast(len(test_data), alpha=0.05)

# %%
fc_series = pd.Series(fc, index=test_data.index)
lower_series = pd.Series(conf[:, 0], index=test_data.index)
upper_series = pd.Series(conf[:, 1], index=test_data.index)
# Plot
plt.figure(figsize=(10,5), dpi=100)
plt.plot(train_data, color = 'blue',label='Обучающая выборка')
plt.plot(test_data, color = 'red', label='Истинные значения')
plt.plot(fc_series, color = 'green',label='Предсказанные значения')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.10)
plt.title('Предсказание стоимости  Bitcoin (ARIMA)')
plt.xlabel('Год')
plt.ylabel('Стоимость')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %%
fc_reshape =fc.reshape(len(test_data),1)

# %%
mae, rmse, si, mape = metrics(fc,test_data['Price'])

print("MAE:", mae)
print("RMSE:", rmse)
print('SI:' + toFixed(si, 2) + "%")
print('MAPE:' + toFixed(mape, 2) + "%")
# Out:
# MAE: 3198.5657443416403
# RMSE: 3537.804888931613
# SI:11.24%
# MAPE:10.96%

# %% [markdown]
# # SARIMA

# %%
train_sizeSARIMA = int(len(stock_data) * 0.85)
train_dataSARIMA = stock_data.iloc[:train_sizeSARIMA]
test_dataSARIMA = stock_data.iloc[train_sizeSARIMA:]

# %%
plt.figure(figsize=(15,8))
plt.grid(True)
plt.xlabel('Год')
plt.ylabel('Стоимость')
plt.plot(train_dataSARIMA, 'blue', label='Обучающие данные')
plt.plot(test_dataSARIMA, 'red', label='Тестовые данные')
plt.legend()

# %%
smodel = pm.auto_arima(train_dataSARIMA, start_p=1, start_q=1,
                         test='adf',
                         max_p=3, max_q=3, m=12,
                         start_P=0, seasonal=True,
                         d=None, D=1, trace=True,
                         error_action='ignore',  
                         suppress_warnings=True, 
                         stepwise=True)

smodel.summary()
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,1,1)[12]             : AIC=inf, Time=2.95 sec
#  ARIMA(0,1,0)(0,1,0)[12]             : AIC=16421.607, Time=0.05 sec
#  ARIMA(1,1,0)(1,1,0)[12]             : AIC=12292.758, Time=0.39 sec
#  ARIMA(0,1,1)(0,1,1)[12]             : AIC=14730.462, Time=0.56 sec
#  ARIMA(1,1,0)(0,1,0)[12]             : AIC=12982.225, Time=0.08 sec
#  ARIMA(1,1,0)(2,1,0)[12]             : AIC=12140.298, Time=1.10 sec
#  ARIMA(1,1,0)(2,1,1)[12]             : AIC=inf, Time=5.81 sec
#  ARIMA(1,1,0)(1,1,1)[12]             : AIC=inf, Time=2.35 sec
#  ARIMA(0,1,0)(2,1,0)[12]             : AIC=16406.834, Time=0.53 sec
#  ARIMA(2,1,0)(2,1,0)[12]             : AIC=12141.913, Time=1.57 sec
#  ARIMA(1,1,1)(2,1,0)[12]             : AIC=12141.916, Time=1.21 sec
#  ARIMA(0,1,1)(2,1,0)[12]             : AIC=14704.406, Time=1.01 sec
#  ARIMA(2,1,1)(2,1,0)[12]             : AIC=12143.790, Time=1.41 sec
#  ARIMA(1,1,0)(2,1,0)[12] intercept   : AIC=12142.264, Time=3.57 sec
#
# Best model:  ARIMA(1,1,0)(2,1,0)[12]
# Total fit time: 22.614 seconds
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                                  y   No. Observations:                 1955
# Model:             SARIMAX(1, 1, 0)x(2, 1, 0, 12)   Log Likelihood               -6066.149
# Date:                            Fri, 19 May 2023   AIC                          12140.298
# Time:                                    20:42:02   BIC                          12162.584
# Sample:                                         0   HQIC                         12148.494
#                                            - 1955
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9650      0.003    310.576      0.000       0.959       0.971
# ar.S.L12      -0.7130      0.012    -61.433      0.000      -0.736      -0.690
# ar.S.L24      -0.2792      0.012    -22.956      0.000      -0.303      -0.255
# sigma2        30.1211      0.389     77.453      0.000      29.359      30.883
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.33   Jarque-Bera (JB):              9203.67
# Prob(Q):                              0.56   Prob(JB):                         0.00
# Heteroskedasticity (H):              13.63   Skew:                            -0.09
# Prob(H) (two-sided):                  0.00   Kurtosis:                        13.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).
# """

# %%
model = SARIMAX(train_data, order=(1,1,0), seasonal_order=(2,1,0,12))
model_fit = model.fit()
print(model_fit.summary())
# Out:
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              Price   No. Observations:                 1955
# Model:             SARIMAX(1, 1, 0)x(2, 1, 0, 12)   Log Likelihood               -6066.149
# Date:                            Fri, 19 May 2023   AIC                          12140.298
# Time:                                    20:42:03   BIC                          12162.584
# Sample:                                01-01-2017   HQIC                         12148.494
#                                      - 05-09-2022
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.9650      0.003    310.576      0.000       0.959       0.971
# ar.S.L12      -0.7130      0.012    -61.433      0.000      -0.736      -0.690
# ar.S.L24      -0.2792      0.012    -22.956      0.000      -0.303      -0.255
# sigma2        30.1211      0.389     77.453      0.000      29.359      30.883
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.33   Jarque-Bera (JB):              9203.67
# Prob(Q):                              0.56   Prob(JB):                         0.00
# Heteroskedasticity (H):              13.63   Skew:                            -0.09
# Prob(H) (two-sided):                  0.00   Kurtosis:                        13.66
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
start_index = len(train_dataSARIMA)
end_index = len(train_dataSARIMA) + len(test_dataSARIMA) - 1
forecast = model_fit.predict(start=start_index, end=end_index)

# %%
plt.figure(figsize=(15,8), dpi=100)
plt.plot(stock_data.index, stock_data['Price'], color = 'blue', label='Исходные данные')
plt.plot(test_dataSARIMA, color = 'red', label='Истинные значения')
plt.plot(test_dataSARIMA.index, forecast, color = 'green', label='Прогноз')
plt.fill_between(lower_series.index, lower_series, upper_series, 
                 color='k', alpha=.10)
plt.xlabel('Год')
plt.ylabel('Стоимость')
plt.legend()
plt.show()

# %%
mae, rmse, si, mape = metrics(forecast,test_data['Price'])

print("MAE:", mae)
print("RMSE:", rmse)
print('SI:' + toFixed(si, 2) + "%")
print('MAPE:' + toFixed(mape, 2) + "%")
# Out:
# MAE: 1975.2778824001057
# RMSE: 2210.1885538353467
# SI:7.02%
# MAPE:6.57%

# %% [markdown]
# # Построение LSTM

# %%
def plot_predictions(test,predicted):
    plt.plot(test, color='red',label='Истинные значения')
    plt.plot(predicted, color='green',label='Предсказанные значения')
    plt.title('Предсказание стоимости Bitcoin')
    plt.xlabel('Год')
    plt.ylabel('Стоимость')
    plt.legend()
    plt.show()

# %%
dateparse = lambda dates: pd.datetime.strptime(dates, '%Y-%m-%d')
stock_data_nn = pd.read_csv('btc.txt',sep=',',
                         index_col='Date', parse_dates=['Date'], date_parser=dateparse).fillna(0)
stock_data_nn = stock_data_nn.rename(columns={'Open': 'Price'})
stock_data_nn
# Out:
#                    Price          High           Low         Close  \
# Date
# 2017-01-01    963.650000   1003.080000    958.690000    998.325000
# 2017-01-02    998.617000   1031.390000    996.702000   1021.750000
# 2017-01-03   1021.599976   1044.079956   1021.599976   1043.839966
# 2017-01-04   1044.400024   1159.420044   1044.400024   1154.729980
# 2017-01-05   1156.729980   1191.099976    910.416992   1013.380005
# ...                  ...           ...           ...           ...
# 2023-04-16  30315.976420  30555.537630  30157.832330  30315.355460
# 2023-04-17  30317.145700  30319.196580  29275.371060  29445.044900
# 2023-04-18  29449.091700  30470.302010  29154.849370  30397.552740
# 2023-04-19  30394.187900  30411.053790  28669.898270  28822.680470
# 2023-04-20  28823.682860  29076.401050  28037.257260  28245.987310
#
#                  Volume
# Date
# 2017-01-01    147775008
# 2017-01-02    222184992
# 2017-01-03    185168000
# 2017-01-04    344945984
# 2017-01-05    510199008
# ...                 ...
# 2023-04-16  12854816417
# 2023-04-17  17872186762
# 2023-04-18  19480529496
# 2023-04-19  24571565421
# 2023-04-20  21340360360
#
# [2301 rows x 5 columns]

# %%
training_set = stock_data_nn[:'2021-12-06'].iloc[:,1:2].values
test_set = stock_data_nn['2021-12-07':].iloc[:,1:2].values

# %%
len(training_set),len(test_set)
# Out:
# (1801, 500)

# %%
plt.figure(figsize=(15,10), dpi=100)
stock_data_nn["Price"][:'2021-12-06'].plot(figsize=(16,4),legend=True)
stock_data_nn["Price"]['2021-12-07':].plot(figsize=(16,4),legend=True)
plt.legend(['Обучающая выборка','Тестовая выборка'])
plt.title('Стоимость Bitcoin')
plt.xlabel('Год')
plt.ylabel('Стоимость')
plt.show()

# %%
sc = MinMaxScaler(feature_range=(0,1))
training_set_scaled = sc.fit_transform(training_set)

# %%
X_train = []
y_train = []
for i in range(60,1801):
    X_train.append(training_set_scaled[i-60:i,0])
    y_train.append(training_set_scaled[i,0])
X_train, y_train = np.array(X_train), np.array(y_train)

# %%
regressor = Sequential()
# 1 слой 
regressor.add(LSTM(units=50, return_sequences=True, input_shape=(X_train.shape[1],1)))
regressor.add(Dropout(0.2))
# 2 слой 
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))
# 3 слой 
regressor.add(LSTM(units=50, return_sequences=True))
regressor.add(Dropout(0.2))
# 4 слой 
regressor.add(LSTM(units=50))
regressor.add(Dropout(0.2))
# Выходной слой
regressor.add(Dense(units=1 , activation='tanh'))


regressor.compile(optimizer=Adam(learning_rate=0.001),loss='mean_squared_error')

history = regressor.fit(X_train,y_train, epochs=100,batch_size=128)
loss_values = history.history['loss']
# Out:
# Epoch 1/100
# 14/14 [==============================] - 4s 70ms/step - loss: 0.0375
# Epoch 2/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0056
# Epoch 3/100
# 14/14 [==============================] - 1s 78ms/step - loss: 0.0035
# Epoch 4/100
# 14/14 [==============================] - 1s 78ms/step - loss: 0.0025
# Epoch 5/100
# 14/14 [==============================] - 1s 79ms/step - loss: 0.0025
# Epoch 6/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0023
# Epoch 7/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0023
# Epoch 8/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0024
# Epoch 9/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0024
# Epoch 10/100
# 14/14 [==============================] - 1s 78ms/step - loss: 0.0023
# Epoch 11/100
# 14/14 [==============================] - 1s 75ms/step - loss: 0.0022
# Epoch 12/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0021
# Epoch 13/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0021
# Epoch 14/100
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0020
# Epoch 15/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0018
# Epoch 16/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0017
# Epoch 17/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0018
# Epoch 18/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0019
# Epoch 19/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0018
# Epoch 20/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0016
# Epoch 21/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0015
# Epoch 22/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0017
# Epoch 23/100
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0016
# Epoch 24/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0017
# Epoch 25/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0015
# Epoch 26/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0015
# Epoch 27/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0014
# Epoch 28/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0015
# Epoch 29/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0014
# Epoch 30/100
# 14/14 [==============================] - 1s 77ms/step - loss: 0.0014
# Epoch 31/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0016
# Epoch 32/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0013
# Epoch 33/100
# 14/14 [==============================] - 1s 77ms/step - loss: 0.0014
# Epoch 34/100
# 14/14 [==============================] - 1s 75ms/step - loss: 0.0014
# Epoch 35/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0014
# Epoch 36/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0014
# Epoch 37/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0012
# Epoch 38/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0012
# Epoch 39/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0013
# Epoch 40/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0011
# Epoch 41/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0011
# Epoch 42/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0011
# Epoch 43/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0013
# Epoch 44/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0012
# Epoch 45/100
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0011
# Epoch 46/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0011
# Epoch 47/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0011
# Epoch 48/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0012
# Epoch 49/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0013
# Epoch 50/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0010
# Epoch 51/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0011
# Epoch 52/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0010
# Epoch 53/100
# 14/14 [==============================] - 1s 75ms/step - loss: 9.8543e-04
# Epoch 54/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0010
# Epoch 55/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0011
# Epoch 56/100
# 14/14 [==============================] - 1s 72ms/step - loss: 9.6877e-04
# Epoch 57/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0010
# Epoch 58/100
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0011
# Epoch 59/100
# 14/14 [==============================] - 1s 72ms/step - loss: 8.9208e-04
# Epoch 60/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0011
# Epoch 61/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0012
# Epoch 62/100
# 14/14 [==============================] - 1s 71ms/step - loss: 0.0011
# Epoch 63/100
# 14/14 [==============================] - 1s 72ms/step - loss: 9.8409e-04
# Epoch 64/100
# 14/14 [==============================] - 1s 73ms/step - loss: 9.1005e-04
# Epoch 65/100
# 14/14 [==============================] - 1s 73ms/step - loss: 9.3303e-04
# Epoch 66/100
# 14/14 [==============================] - 1s 73ms/step - loss: 9.5830e-04
# Epoch 67/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0010
# Epoch 68/100
# 14/14 [==============================] - 1s 76ms/step - loss: 8.3544e-04
# Epoch 69/100
# 14/14 [==============================] - 1s 73ms/step - loss: 8.2153e-04
# Epoch 70/100
# 14/14 [==============================] - 1s 73ms/step - loss: 8.4607e-04
# Epoch 71/100
# 14/14 [==============================] - 1s 71ms/step - loss: 9.9030e-04
# Epoch 72/100
# 14/14 [==============================] - 1s 73ms/step - loss: 8.8302e-04
# Epoch 73/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0010
# Epoch 74/100
# 14/14 [==============================] - 1s 73ms/step - loss: 9.3591e-04
# Epoch 75/100
# 14/14 [==============================] - 1s 72ms/step - loss: 8.6983e-04
# Epoch 76/100
# 14/14 [==============================] - 1s 73ms/step - loss: 8.2552e-04
# Epoch 77/100
# 14/14 [==============================] - 1s 73ms/step - loss: 8.9066e-04
# Epoch 78/100
# 14/14 [==============================] - 1s 72ms/step - loss: 9.2264e-04
# Epoch 79/100
# 14/14 [==============================] - 1s 73ms/step - loss: 8.5392e-04
# Epoch 80/100
# 14/14 [==============================] - 1s 74ms/step - loss: 8.2246e-04
# Epoch 81/100
# 14/14 [==============================] - 1s 73ms/step - loss: 8.3936e-04
# Epoch 82/100
# 14/14 [==============================] - 1s 74ms/step - loss: 9.1789e-04
# Epoch 83/100
# 14/14 [==============================] - 1s 77ms/step - loss: 8.4569e-04
# Epoch 84/100
# 14/14 [==============================] - 1s 76ms/step - loss: 9.3727e-04
# Epoch 85/100
# 14/14 [==============================] - 1s 77ms/step - loss: 8.5200e-04
# Epoch 86/100
# 14/14 [==============================] - 1s 76ms/step - loss: 8.2065e-04
# Epoch 87/100
# 14/14 [==============================] - 1s 75ms/step - loss: 7.7177e-04
# Epoch 88/100
# 14/14 [==============================] - 1s 74ms/step - loss: 8.1165e-04
# Epoch 89/100
# 14/14 [==============================] - 1s 75ms/step - loss: 7.7085e-04
# Epoch 90/100
# 14/14 [==============================] - 1s 74ms/step - loss: 7.8208e-04
# Epoch 91/100
# 14/14 [==============================] - 1s 74ms/step - loss: 7.5587e-04
# Epoch 92/100
# 14/14 [==============================] - 1s 74ms/step - loss: 7.5537e-04
# Epoch 93/100
# 14/14 [==============================] - 1s 74ms/step - loss: 7.8745e-04
# Epoch 94/100
# 14/14 [==============================] - 1s 74ms/step - loss: 7.9005e-04
# Epoch 95/100
# 14/14 [==============================] - 1s 73ms/step - loss: 8.1297e-04
# Epoch 96/100
# 14/14 [==============================] - 1s 73ms/step - loss: 6.7430e-04
# Epoch 97/100
# 14/14 [==============================] - 1s 73ms/step - loss: 7.0971e-04
# Epoch 98/100
# 14/14 [==============================] - 1s 72ms/step - loss: 7.6707e-04
# Epoch 99/100
# 14/14 [==============================] - 1s 73ms/step - loss: 8.3029e-04
# Epoch 100/100
# 14/14 [==============================] - 1s 73ms/step - loss: 7.2782e-04

# %%
plt.plot(loss_values)
plt.title('График потерь')
plt.xlabel('Эпоха')
plt.ylabel('Потери')
plt.show()

# %%
dataset_total = pd.concat((stock_data_nn["Price"][:'2021-12-06'],stock_data_nn["Price"]['2021-12-07':]),axis=0)
inputs = dataset_total[len(dataset_total)-len(test_set) - 60:].values
inputs = inputs.reshape(-1,1)
inputs  = sc.transform(inputs)

# %%
X_test = []
for i in range(60,560):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
predicted_stock_price = regressor.predict(X_test)
predicted_stock_price = sc.inverse_transform(predicted_stock_price)

# %%
plot_predictions(test_set,predicted_stock_price)

# %%
mae, rmse, si, mape = metrics(predicted_stock_price,test_set)

print("MAE:", mae)
print("RMSE:", rmse)
print('SI:' + toFixed(si, 2) + "%")
print('MAPE:' + toFixed(mape, 2) + "%")
# Out:
# MAE: 1448.3572921425002
# RMSE: 2044.872363496488
# SI:7.08%
# MAPE:4.82%

# %% [markdown]
# # GRU

# %%
regressorGRU = Sequential()
# 1 слой 
regressorGRU.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1)))
regressorGRU.add(Dropout(0.2))
# 2 слой 
regressorGRU.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1)))
regressorGRU.add(Dropout(0.2))
# 3 слой 
regressorGRU.add(GRU(units=50, return_sequences=True, input_shape=(X_train.shape[1],1)))
regressorGRU.add(Dropout(0.2))
# 4 слой 
regressorGRU.add(GRU(units=50))
regressorGRU.add(Dropout(0.2))
# Выходной слой
regressorGRU.add(Dense(units=1, activation='tanh'))

regressorGRU.compile(optimizer=Adam(learning_rate=0.001),loss='mean_squared_error')

historyGRU = regressorGRU.fit(X_train,y_train,epochs=100,batch_size=128)
loss_valuesGRU = history.history['loss']
# Out:
# Epoch 1/100
# 14/14 [==============================] - 4s 76ms/step - loss: 0.0572
# Epoch 2/100
# 14/14 [==============================] - 1s 75ms/step - loss: 0.0070
# Epoch 3/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0030
# Epoch 4/100
# 14/14 [==============================] - 1s 75ms/step - loss: 0.0027
# Epoch 5/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0021
# Epoch 6/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0020
# Epoch 7/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0022
# Epoch 8/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0018
# Epoch 9/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0019
# Epoch 10/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0017
# Epoch 11/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0017
# Epoch 12/100
# 14/14 [==============================] - 1s 75ms/step - loss: 0.0015
# Epoch 13/100
# 14/14 [==============================] - 1s 76ms/step - loss: 0.0016
# Epoch 14/100
# 14/14 [==============================] - 1s 75ms/step - loss: 0.0016
# Epoch 15/100
# 14/14 [==============================] - 1s 75ms/step - loss: 0.0014
# Epoch 16/100
# 14/14 [==============================] - 1s 75ms/step - loss: 0.0014
# Epoch 17/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0014
# Epoch 18/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0013
# Epoch 19/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0013
# Epoch 20/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0014
# Epoch 21/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0013
# Epoch 22/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0012
# Epoch 23/100
# 14/14 [==============================] - 1s 72ms/step - loss: 0.0012
# Epoch 24/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0012
# Epoch 25/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0012
# Epoch 26/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0011
# Epoch 27/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0011
# Epoch 28/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0013
# Epoch 29/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0011
# Epoch 30/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0012
# Epoch 31/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0011
# Epoch 32/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0011
# Epoch 33/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0011
# Epoch 34/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0011
# Epoch 35/100
# 14/14 [==============================] - 1s 75ms/step - loss: 9.8687e-04
# Epoch 36/100
# 14/14 [==============================] - 1s 73ms/step - loss: 9.8673e-04
# Epoch 37/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0011
# Epoch 38/100
# 14/14 [==============================] - 1s 73ms/step - loss: 0.0010
# Epoch 39/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0010
# Epoch 40/100
# 14/14 [==============================] - 1s 73ms/step - loss: 9.8080e-04
# Epoch 41/100
# 14/14 [==============================] - 1s 73ms/step - loss: 9.9729e-04
# Epoch 42/100
# 14/14 [==============================] - 1s 74ms/step - loss: 0.0010
# Epoch 43/100
# 14/14 [==============================] - 1s 73ms/step - loss: 9.5870e-04
# Epoch 44/100
# 14/14 [==============================] - 1s 75ms/step - loss: 8.9186e-04
# Epoch 45/100
# 14/14 [==============================] - 1s 74ms/step - loss: 9.7198e-04
# Epoch 46/100
# 14/14 [==============================] - 1s 74ms/step - loss: 8.9983e-04
# Epoch 47/100
# 14/14 [==============================] - 1s 74ms/step - loss: 8.7695e-04
# Epoch 48/100
# 14/14 [==============================] - 1s 74ms/step - loss: 8.8068e-04
# Epoch 49/100
# 14/14 [==============================] - 1s 74ms/step - loss: 9.4601e-04
# Epoch 50/100
# 14/14 [==============================] - 1s 75ms/step - loss: 8.9602e-04
# Epoch 51/100
# 14/14 [==============================] - 1s 74ms/step - loss: 8.8391e-04
# Epoch 52/100
# 14/14 [==============================] - 1s 73ms/step - loss: 8.4137e-04
# Epoch 53/100
# 14/14 [==============================] - 1s 75ms/step - loss: 0.0010
# Epoch 54/100
# 14/14 [==============================] - 1s 73ms/step - loss: 9.9677e-04
# Epoch 55/100
# 14/14 [==============================] - 1s 73ms/step - loss: 8.4008e-04
# Epoch 56/100
# 14/14 [==============================] - 1s 74ms/step - loss: 8.9357e-04
# Epoch 57/100
# 14/14 [==============================] - 1s 73ms/step - loss: 8.2334e-04
# Epoch 58/100
# 14/14 [==============================] - 1s 75ms/step - loss: 8.7115e-04
# Epoch 59/100
# 14/14 [==============================] - 1s 74ms/step - loss: 8.1627e-04
# Epoch 60/100
# 14/14 [==============================] - 1s 75ms/step - loss: 8.5728e-04
# Epoch 61/100
# 14/14 [==============================] - 1s 74ms/step - loss: 8.9298e-04
# Epoch 62/100
# 14/14 [==============================] - 1s 74ms/step - loss: 8.1470e-04
# Epoch 63/100
# 14/14 [==============================] - 1s 75ms/step - loss: 8.7084e-04
# Epoch 64/100
# 14/14 [==============================] - 1s 73ms/step - loss: 7.7588e-04
# Epoch 65/100
# 14/14 [==============================] - 1s 74ms/step - loss: 9.3480e-04
# Epoch 66/100
# 14/14 [==============================] - 1s 74ms/step - loss: 8.4608e-04
# Epoch 67/100
# 14/14 [==============================] - 1s 74ms/step - loss: 8.4723e-04
# Epoch 68/100
# 14/14 [==============================] - 1s 74ms/step - loss: 7.6889e-04
# Epoch 69/100
# 14/14 [==============================] - 1s 75ms/step - loss: 7.8942e-04
# Epoch 70/100
# 14/14 [==============================] - 1s 74ms/step - loss: 8.0829e-04
# Epoch 71/100
# 14/14 [==============================] - 1s 75ms/step - loss: 6.7904e-04
# Epoch 72/100
# 14/14 [==============================] - 1s 73ms/step - loss: 8.6382e-04
# Epoch 73/100
# 14/14 [==============================] - 1s 74ms/step - loss: 7.4365e-04
# Epoch 74/100
# 14/14 [==============================] - 1s 77ms/step - loss: 7.8864e-04
# Epoch 75/100
# 14/14 [==============================] - 1s 75ms/step - loss: 8.2738e-04
# Epoch 76/100
# 14/14 [==============================] - 1s 75ms/step - loss: 8.0891e-04
# Epoch 77/100
# 14/14 [==============================] - 1s 74ms/step - loss: 7.2296e-04
# Epoch 78/100
# 14/14 [==============================] - 1s 75ms/step - loss: 6.6578e-04
# Epoch 79/100
# 14/14 [==============================] - 1s 74ms/step - loss: 7.7407e-04
# Epoch 80/100
# 14/14 [==============================] - 1s 71ms/step - loss: 9.9202e-04
# Epoch 81/100
# 14/14 [==============================] - 1s 72ms/step - loss: 7.9956e-04
# Epoch 82/100
# 14/14 [==============================] - 1s 72ms/step - loss: 8.1359e-04
# Epoch 83/100
# 14/14 [==============================] - 1s 73ms/step - loss: 9.0334e-04
# Epoch 84/100
# 14/14 [==============================] - 1s 75ms/step - loss: 7.3187e-04
# Epoch 85/100
# 14/14 [==============================] - 1s 75ms/step - loss: 7.5211e-04
# Epoch 86/100
# 14/14 [==============================] - 1s 77ms/step - loss: 7.0525e-04
# Epoch 87/100
# 14/14 [==============================] - 1s 74ms/step - loss: 7.8276e-04
# Epoch 88/100
# 14/14 [==============================] - 1s 74ms/step - loss: 7.5493e-04
# Epoch 89/100
# 14/14 [==============================] - 1s 75ms/step - loss: 7.2782e-04
# Epoch 90/100
# 14/14 [==============================] - 1s 74ms/step - loss: 7.1801e-04
# Epoch 91/100
# 14/14 [==============================] - 1s 76ms/step - loss: 6.8710e-04
# Epoch 92/100
# 14/14 [==============================] - 1s 74ms/step - loss: 7.0146e-04
# Epoch 93/100
# 14/14 [==============================] - 1s 74ms/step - loss: 7.2647e-04
# Epoch 94/100
# 14/14 [==============================] - 1s 75ms/step - loss: 7.9717e-04
# Epoch 95/100
# 14/14 [==============================] - 1s 74ms/step - loss: 8.0762e-04
# Epoch 96/100
# 14/14 [==============================] - 1s 75ms/step - loss: 6.7363e-04
# Epoch 97/100
# 14/14 [==============================] - 1s 74ms/step - loss: 7.3714e-04
# Epoch 98/100
# 14/14 [==============================] - 1s 74ms/step - loss: 8.7553e-04
# Epoch 99/100
# 14/14 [==============================] - 1s 74ms/step - loss: 6.9861e-04
# Epoch 100/100
# 14/14 [==============================] - 1s 74ms/step - loss: 6.8333e-04

# %%
plt.plot(loss_valuesGRU)
plt.title('График потерь')
plt.xlabel('Эпоха')
plt.ylabel('Потери')
plt.show()

# %%
X_test = []
for i in range(60,560):
    X_test.append(inputs[i-60:i,0])
X_test = np.array(X_test)
X_test = np.reshape(X_test, (X_test.shape[0],X_test.shape[1],1))
GRU_predicted_stock_price = regressorGRU.predict(X_test)
GRU_predicted_stock_price = sc.inverse_transform(GRU_predicted_stock_price)

# %%
plot_predictions(test_set,GRU_predicted_stock_price)

# %%
mae_gru = mean_absolute_error(test_set, GRU_predicted_stock_price)
print('MAE: '+str(mae_gru))
rmse_gru = math.sqrt(mean_squared_error(test_set, GRU_predicted_stock_price))
print('RMSE: '+str(rmse_gru))
si = (rmse_gru/mn)*100
print('SI:' + toFixed(si, 2) + "%")
mape_gru = (np.mean(np.abs(GRU_predicted_stock_price - test_set)/np.abs(test_set)))*100
#print('MAPE: '+str(mape_gru))
print('MAPE:' + toFixed(mape_gru, 2) + "%")
# Out:
# MAE: 1714.6447926318747
# RMSE: 2044.7973790110075
# SI:7.08%
# MAPE:6.35%
